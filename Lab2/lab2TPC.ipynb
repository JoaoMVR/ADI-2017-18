# %%
# TPC Lab 2

# alinea C

import numpy as np

x = 0.1667

monopoly = np.array([[0, x, x , x, x, x, x, 0],
               [0, 0, x, x, x, x, x, x],
               [x, 0, 0, x, x, x, x, x],
               [x, x, 0, 0, x, x, x, x],
               [x, x, x, 0, 0, x, x, x],
               [x, x, x, x, 0, 0, x, x],
               [0, 0, 1, 0, 0, 0, 0, 0],
               [x, x, x, x, x, x, 0, 0]])

print(monopoly)

C = np.dot(monopoly, monopoly)
print ("\n\n\n", C)
B = np.linalg.matrix_power(monopoly, 3)

print("\n\n\n", B)

np.linalg.eig(monopoly)
# Out:
# [[ 0.      0.1667  0.1667  0.1667  0.1667  0.1667  0.1667  0.    ]
#  [ 0.      0.      0.1667  0.1667  0.1667  0.1667  0.1667  0.1667]
#  [ 0.1667  0.      0.      0.1667  0.1667  0.1667  0.1667  0.1667]
#  [ 0.1667  0.1667  0.      0.      0.1667  0.1667  0.1667  0.1667]
#  [ 0.1667  0.1667  0.1667  0.      0.      0.1667  0.1667  0.1667]
#  [ 0.1667  0.1667  0.1667  0.1667  0.      0.      0.1667  0.1667]
#  [ 0.      0.      1.      0.      0.      0.      0.      0.    ]
#  [ 0.1667  0.1667  0.1667  0.1667  0.1667  0.1667  0.      0.    ]]
#
#
#
#  [[ 0.11115556  0.08336667  0.25006667  0.08336667  0.08336667  0.11115556
#    0.13894445  0.13894445]
#  [ 0.13894445  0.11115556  0.25006667  0.08336667  0.08336667  0.11115556
#    0.11115556  0.11115556]
#  [ 0.11115556  0.13894445  0.27785556  0.08336667  0.08336667  0.11115556
#    0.11115556  0.08336667]
#  [ 0.08336667  0.11115556  0.30564445  0.11115556  0.08336667  0.11115556
#    0.11115556  0.08336667]
# ...
